# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import cuqi
# Out:
# 3rd party engines available for cuqi: astra

# %% [markdown]
# # Priors on smooth and discrete smooth signals
# In this notebook we bla bla

# %%
    xln = np.linspace(0,10,200)
    x_sm = np.sin(xln)+0.5*np.cos(xln/2)

    xd = np.zeros(200); xd[10:40] = 0.3; xd[45:80] = -0.3; xd[90:110]=0.5; xd[150:185]=-0.6

    x_disc = x_sm + xd

    plt.plot(xln,x_sm,xln,x_disc)

# %% [markdown]
# Simulating and adding gaussian noise to data

# %%
model = cuqi.model.LinearModel(A)
likelihood = cuqi.distribution.GaussianPrec(mean=model, prec=l*I).to_likelihood(y_obs)
prior = cuqi.distribution.GaussianPrec(mean=np.zeros(n), prec=d*L)
BP = cuqi.problem.BayesianProblem(likelihood, prior)
BP.UQ(exact=xt)
